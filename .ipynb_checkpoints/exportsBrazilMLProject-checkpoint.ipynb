# %%
#bibliotecas utilizadas
#pip install pandas

import pandas as pd

# %% [markdown]
# ### Download Dataset

# %%
#pip install kaggle
#!kaggle datasets download -d hugovallejo/brazil-exports
#!unzip brazil-exports.zip 
#!rm -rf brazil-exports.zip

# %%
data = pd.read_csv('exportacao_full.csv')
column_names_mapping = {
    'Year': 'Ano',
    'Month': 'Mes',
    'Country': 'Pais',
    'City': 'Cidade',
    'SH4 Code': 'CodigoSH4',
    'SH4 Description': 'DescricaoSH4',
    'SH2 Code': 'CodigoSH2',
    'SH2 Description': 'DescricaoSH2',
    'Economic Block': 'Blocoeconomico',
    'US$ FOB': 'ValorFOBUS',
    'Net Weight': 'PesoLiquido'
}

data.rename(columns=column_names_mapping, inplace=True)

data.head()
# Out:
#     Ano  Mes         Pais          Cidade  CodigoSH4  \
# 0  2010    1  Afghanistan     Itajaí - SC        207
# 1  2010    1  Afghanistan       Lapa - PR        207
# 2  2010    1  Afghanistan   Rolândia - PR        207
# 3  2010    1  Afghanistan  São Paulo - SP        207
# 4  2010    1  Afghanistan      Xaxim - SC        207
#
#                                         DescricaoSH4  CodigoSH2  \
# 0  Meat and edible offal, of the poultry of headi...          2
# 1  Meat and edible offal, of the poultry of headi...          2
# 2  Meat and edible offal, of the poultry of headi...          2
# 3  Meat and edible offal, of the poultry of headi...          2
# 4  Meat and edible offal, of the poultry of headi...          2
#
#                  DescricaoSH2            Blocoeconomico  ValorFOBUS  \
# 0  Meat and edible meat offal  Asia (minus MIDDLE EAST)      197162
# 1  Meat and edible meat offal  Asia (minus MIDDLE EAST)      114570
# 2  Meat and edible meat offal  Asia (minus MIDDLE EAST)       72900
# 3  Meat and edible meat offal  Asia (minus MIDDLE EAST)      153593
# 4  Meat and edible meat offal  Asia (minus MIDDLE EAST)       26739
#
#    PesoLiquido
# 0        99945
# 1        76989
# 2        54000
# 3       106541
# 4        24990

# %%
# Verifica a quantidade de valores nulos em cada coluna
null_counts = data.isna().sum()

# Exibe a quantidade de valores nulos em cada coluna
print(null_counts)
# Out:
# Ano               0
# Mes               0
# Pais              0
# Cidade            0
# CodigoSH4         0
# DescricaoSH4      0
# CodigoSH2         0
# DescricaoSH2      0
# Blocoeconomico    0
# ValorFOBUS        0
# PesoLiquido       0
# dtype: int64
